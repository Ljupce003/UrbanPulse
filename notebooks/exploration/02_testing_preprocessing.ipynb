# %%
import pandas as pd

# ---------- CONFIG ----------
traffic_path = "../../data/raw/traffic.csv"
weather_path = "../../data/raw/weather.csv"
pollution_path = "../../data/raw/pollution.csv"

# If column names differ, change these later
POSSIBLE_TIME_COLUMNS = ["timestamp", "date", "datetime", "time"]

# ---------- HELPER FUNCTION ----------
def analyze_dataset(name, path):
    print(f"\n{'='*50}")
    print(f"DATASET: {name}")
    print(f"{'='*50}")

    # Load
    df = pd.read_csv(path)

    # Basic info
    print("\n--- Shape ---")
    print(df.shape)

    print("\n--- Columns ---")
    print(df.columns.tolist())

    print("\n--- Head ---")
    print(df.head())

    print("\n--- Info ---")
    print(df.info())

    # Try to find time column
    time_col = None
    for col in df.columns:
        if col.lower() in POSSIBLE_TIME_COLUMNS:
            time_col = col
            break

    if time_col:
        print(f"\n--- Detected time column: {time_col} ---")

        # Convert to datetime
        try:
            df[time_col] = pd.to_datetime(df[time_col])
            print("Converted to datetime successfully")

            print("\n--- Time range ---")
            print("Min:", df[time_col].min())
            print("Max:", df[time_col].max())

        except Exception as e:
            print("Failed to convert time column:", e)
    else:
        print("\n--- No obvious time column detected ---")

    # Missing values
    print("\n--- Missing values ---")
    print(df.isnull().sum())

    # Numeric stats
    print("\n--- Describe (numeric) ---")
    print(df.describe())

    return df

# %%
# ---------- RUN ----------
traffic_df = analyze_dataset("TRAFFIC", traffic_path)
weather_df = analyze_dataset("WEATHER", weather_path)
pollution_df = analyze_dataset("POLLUTION", pollution_path)
# Out:
# ==================================================
# DATASET: TRAFFIC
# ==================================================
#
# --- Shape ---
# (1875154, 14)
#
# --- Columns ---
# ['RequestID', 'Boro', 'Yr', 'M', 'D', 'HH', 'MM', 'Vol', 'SegmentID', 'WktGeom', 'street', 'fromSt', 'toSt', 'Direction']
#
# --- Head ---
#    RequestID    Boro    Yr  M  D  HH  MM Vol  SegmentID  \
# 0      12512  Queens  2013  3  7   4  15   5      55135
# 1      12512  Queens  2013  3  7   4  30   8      55135
# 2      12512  Queens  2013  3  7   4  45   8      55135
# 3      12512  Queens  2013  3  7   5   0   7      55135
# 4      12512  Queens  2013  3  7   5  15   9      55135
#
#                       WktGeom  street     fromSt           toSt Direction
# 0  POINT (1035363.4 185093.4)  122 PL  SUTTER AV  ROCKAWAY BLVD        SB
# 1  POINT (1035363.4 185093.4)  122 PL  SUTTER AV  ROCKAWAY BLVD        SB
# 2  POINT (1035363.4 185093.4)  122 PL  SUTTER AV  ROCKAWAY BLVD        SB
# 3  POINT (1035363.4 185093.4)  122 PL  SUTTER AV  ROCKAWAY BLVD        SB
# 4  POINT (1035363.4 185093.4)  122 PL  SUTTER AV  ROCKAWAY BLVD        SB
#
# --- Info ---
# <class 'pandas.DataFrame'>
# RangeIndex: 1875154 entries, 0 to 1875153
# Data columns (total 14 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   RequestID  int64
#  1   Boro       str
#  2   Yr         int64
#  3   M          int64
#  4   D          int64
#  5   HH         int64
#  6   MM         int64
#  7   Vol        str
#  8   SegmentID  int64
#  9   WktGeom    str
#  10  street     str
#  11  fromSt     str
#  12  toSt       str
#  13  Direction  str
# dtypes: int64(7), str(7)
# memory usage: 200.3 MB
# None
#
# --- No obvious time column detected ---
#
# --- Missing values ---
# RequestID       0
# Boro            0
# Yr              0
# M               0
# D               0
# HH              0
# MM              0
# Vol             0
# SegmentID       0
# WktGeom         0
# street          0
# fromSt          0
# toSt         1246
# Direction       0
# dtype: int64
#
# --- Describe (numeric) ---
#           RequestID            Yr             M             D            HH  \
# count  1.875154e+06  1.875154e+06  1.875154e+06  1.875154e+06  1.875154e+06
# mean   2.192540e+04  2.016007e+03  6.324533e+00  1.550962e+01  1.150049e+01
# std    1.124833e+04  4.950547e+00  3.326478e+00  8.572008e+00  6.921397e+00
# min    1.139000e+03  2.000000e+03  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    1.202300e+04  2.012000e+03  3.000000e+00  8.000000e+00  6.000000e+00
# 50%    2.255300e+04  2.016000e+03  6.000000e+00  1.500000e+01  1.100000e+01
# 75%    3.238400e+04  2.020000e+03  9.000000e+00  2.300000e+01  1.700000e+01
# max    3.992000e+04  2.026000e+03  1.200000e+01  3.100000e+01  2.300000e+01
#
#                  MM     SegmentID
# count  1.875154e+06  1.875154e+06
# mean   2.242194e+01  4.218907e+05
# std    1.679804e+01  1.667780e+06
# min    0.000000e+00  4.400000e+01
# 25%    0.000000e+00  4.451800e+04
# 50%    1.500000e+01  8.887700e+04
# 75%    3.000000e+01  1.542730e+05
# max    5.000000e+01  9.017010e+06
#
# ==================================================
# DATASET: WEATHER
# ==================================================
#
# --- Shape ---
# (2322, 11)
#
# --- Columns ---
# ['date', 'tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres', 'tsun']
#
# --- Head ---
#                   date  tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  \
# 0  2020-01-01 00:00:00   3.6   1.7   5.0   NaN   NaN   NaN  17.3   NaN
# 1  2020-01-02 00:00:00   4.7   0.6   8.9   NaN   NaN   NaN  12.4   NaN
# 2  2020-01-03 00:00:00   7.6   6.7   8.3   NaN   NaN   NaN   8.4   NaN
# 3  2020-01-04 00:00:00   8.2   6.7   9.4   NaN   NaN   NaN   5.7   NaN
# 4  2020-01-05 00:00:00   4.6   2.8   7.2   NaN   NaN   NaN   8.2   NaN
#
#      pres  tsun
# 0  1008.2   NaN
# 1  1013.9   NaN
# 2  1010.2   NaN
# 3  1003.7   NaN
# 4  1010.1   NaN
#
# --- Info ---
# <class 'pandas.DataFrame'>
# RangeIndex: 2322 entries, 0 to 2321
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2322 non-null   str
#  1   tavg    2299 non-null   float64
#  2   tmin    2290 non-null   float64
#  3   tmax    2290 non-null   float64
#  4   prcp    1577 non-null   float64
#  5   snow    0 non-null      float64
#  6   wdir    0 non-null      float64
#  7   wspd    2299 non-null   float64
#  8   wpgt    0 non-null      float64
#  9   pres    2258 non-null   float64
#  10  tsun    0 non-null      float64
# dtypes: float64(10), str(1)
# memory usage: 199.7 KB
# None
#
# --- Detected time column: date ---
# Converted to datetime successfully
#
# --- Time range ---
# Min: 2020-01-01 00:00:00
# Max: 2026-05-10 00:00:00
#
# --- Missing values ---
# date       0
# tavg      23
# tmin      32
# tmax      32
# prcp     745
# snow    2322
# wdir    2322
# wspd      23
# wpgt    2322
# pres      64
# tsun    2322
# dtype: int64
#
# --- Describe (numeric) ---
#                       date         tavg         tmin         tmax  \
# count                 2322  2299.000000  2290.000000  2290.000000
# mean   2023-03-06 12:00:00    13.675076    10.254017    17.796769
# min    2020-01-01 00:00:00   -10.700000   -16.100000    -6.700000
# 25%    2021-08-03 06:00:00     6.200000     3.100000     9.500000
# 50%    2023-03-06 12:00:00    13.600000    10.000000    18.100000
# 75%    2024-10-06 18:00:00    21.900000    18.300000    26.100000
# max    2026-05-10 00:00:00    33.200000    27.400000    42.800000
# std                    NaN     9.082869     8.979281     9.642371
#
#               prcp  snow  wdir         wspd  wpgt         pres  tsun
# count  1577.000000   0.0   0.0  2299.000000   0.0  2258.000000   0.0
# mean      2.183259   NaN   NaN    10.928273   NaN  1016.977812   NaN
# min       0.000000   NaN   NaN     2.600000   NaN   989.700000   NaN
# 25%       0.000000   NaN   NaN     7.750000   NaN  1012.400000   NaN
# 50%       0.000000   NaN   NaN     9.800000   NaN  1016.700000   NaN
# 75%       0.700000   NaN   NaN    13.000000   NaN  1021.775000   NaN
# max      78.900000   NaN   NaN    39.100000   NaN  1046.800000   NaN
# std       6.675948   NaN   NaN     4.561272   NaN     7.333925   NaN
#
# ==================================================
# DATASET: POLLUTION
# ==================================================
#
# --- Shape ---
# (5000, 15)
#
# --- Columns ---
# ['location_id', 'location_name', 'parameter', 'value', 'unit', 'datetimeUtc', 'datetimeLocal', 'timezone', 'latitude', 'longitude', 'country_iso', 'isMobile', 'isMonitor', 'owner_name', 'provider']
#
# --- Head ---
#    location_id                      location_name parameter      value   unit  \
# 0      6166696  Downtown Manhattan – FiDi/Seaport       pm1   7.992444  µg/m³
# 1      6166696  Downtown Manhattan – FiDi/Seaport       pm1   8.272333  µg/m³
# 2      6166696  Downtown Manhattan – FiDi/Seaport       pm1   8.261000  µg/m³
# 3      6166696  Downtown Manhattan – FiDi/Seaport       pm1  10.963667  µg/m³
# 4      6166696  Downtown Manhattan – FiDi/Seaport       pm1  12.103333  µg/m³
#
#             datetimeUtc              datetimeLocal          timezone  \
# 0  2025-12-16T04:00:00Z  2025-12-15T23:00:00-05:00  America/New_York
# 1  2025-12-16T05:00:00Z  2025-12-16T00:00:00-05:00  America/New_York
# 2  2025-12-16T06:00:00Z  2025-12-16T01:00:00-05:00  America/New_York
# 3  2025-12-16T07:00:00Z  2025-12-16T02:00:00-05:00  America/New_York
# 4  2025-12-16T08:00:00Z  2025-12-16T03:00:00-05:00  America/New_York
#
#    latitude  longitude  country_iso  isMobile  isMonitor   owner_name  \
# 0   40.7068    -74.005          NaN       NaN        NaN  AirGradient
# 1   40.7068    -74.005          NaN       NaN        NaN  AirGradient
# 2   40.7068    -74.005          NaN       NaN        NaN  AirGradient
# 3   40.7068    -74.005          NaN       NaN        NaN  AirGradient
# 4   40.7068    -74.005          NaN       NaN        NaN  AirGradient
#
#       provider
# 0  AirGradient
# 1  AirGradient
# 2  AirGradient
# 3  AirGradient
# 4  AirGradient
#
# --- Info ---
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   location_id    5000 non-null   int64
#  1   location_name  5000 non-null   str
#  2   parameter      5000 non-null   str
#  3   value          5000 non-null   float64
#  4   unit           5000 non-null   str
#  5   datetimeUtc    5000 non-null   str
#  6   datetimeLocal  5000 non-null   str
#  7   timezone       5000 non-null   str
#  8   latitude       5000 non-null   float64
#  9   longitude      5000 non-null   float64
#  10  country_iso    0 non-null      float64
#  11  isMobile       0 non-null      float64
#  12  isMonitor      0 non-null      float64
#  13  owner_name     5000 non-null   str
#  14  provider       5000 non-null   str
# dtypes: float64(6), int64(1), str(8)
# memory usage: 586.1 KB
# None
#
# --- No obvious time column detected ---
#
# --- Missing values ---
# location_id         0
# location_name       0
# parameter           0
# value               0
# unit                0
# datetimeUtc         0
# datetimeLocal       0
# timezone            0
# latitude            0
# longitude           0
# country_iso      5000
# isMobile         5000
# isMonitor        5000
# owner_name          0
# provider            0
# dtype: int64
#
# --- Describe (numeric) ---
#        location_id        value      latitude  longitude  country_iso  \
# count       5000.0  5000.000000  5.000000e+03   5000.000          0.0
# mean     6166696.0    99.567816  4.070680e+01    -74.005          NaN
# std            0.0   230.702984  1.421228e-14      0.000          NaN
# min      6166696.0    -3.228500  4.070680e+01    -74.005          NaN
# 25%      6166696.0     4.086792  4.070680e+01    -74.005          NaN
# 50%      6166696.0    12.930583  4.070680e+01    -74.005          NaN
# 75%      6166696.0    50.017042  4.070680e+01    -74.005          NaN
# max      6166696.0  1974.000505  4.070680e+01    -74.005          NaN
#
#        isMobile  isMonitor
# count       0.0        0.0
# mean        NaN        NaN
# std         NaN        NaN
# min         NaN        NaN
# 25%         NaN        NaN
# 50%         NaN        NaN
# 75%         NaN        NaN
# max         NaN        NaN

# %%
import pandas as pd

traffic = pd.read_csv("../../data/raw/traffic.csv")

# Fix volume (it's string now)
traffic['Vol'] = pd.to_numeric(traffic['Vol'], errors='coerce')

# Build timestamp
traffic['timestamp'] = pd.to_datetime(
    traffic[['Yr', 'M', 'D', 'HH', 'MM']]
    .rename(columns={
        'Yr': 'year', 'M': 'month', 'D': 'day',
        'HH': 'hour', 'MM': 'minute'
    })
)

# Keep only needed columns
traffic = traffic[['timestamp', 'Vol']]

# Convert to hourly (sum makes sense for traffic)
traffic = traffic.set_index('timestamp').resample('1h').sum().reset_index()
traffic.rename(columns={'Vol': 'traffic_volume'}, inplace=True)

traffic.head()
# Out:
#             timestamp  traffic_volume
# 0 2000-01-01 00:00:00           962.0
# 1 2000-01-01 01:00:00          1359.0
# 2 2000-01-01 02:00:00          1488.0
# 3 2000-01-01 03:00:00          1501.0
# 4 2000-01-01 04:00:00          1368.0

# %%
weather = pd.read_csv("../../data/raw/weather.csv")

weather['timestamp'] = pd.to_datetime(weather['date'])

# Keep only relevant columns
weather = weather[['timestamp', 'tavg', 'prcp']]

# Set index
weather = weather.set_index('timestamp')

# Convert daily → hourly by forward filling
weather = weather.resample('1h').ffill().reset_index()

# Rename columns
weather.rename(columns={
    'tavg': 'temperature',
    'prcp': 'precipitation'
}, inplace=True)

# Fill precipitation NaN with 0 (means no rain)
weather['precipitation'] = weather['precipitation'].fillna(0)

weather.head()
# Out:
#             timestamp  temperature  precipitation
# 0 2020-01-01 00:00:00          3.6            0.0
# 1 2020-01-01 01:00:00          3.6            0.0
# 2 2020-01-01 02:00:00          3.6            0.0
# 3 2020-01-01 03:00:00          3.6            0.0
# 4 2020-01-01 04:00:00          3.6            0.0

# %%
pollution = pd.read_csv("../../data/raw/pollution.csv")

# Convert timestamp
pollution['timestamp'] = pd.to_datetime(pollution['datetimeUtc'])

# Keep only relevant columns
pollution = pollution[['timestamp', 'parameter', 'value']]

# Pivot → columns = parameters (pm1, pm2.5, etc.)
pollution = pollution.pivot_table(
    index='timestamp',
    columns='parameter',
    values='value',
    aggfunc='mean'
).reset_index()

# Optional: keep only one pollutant (simpler)
if 'pm25' in pollution.columns:
    pollution = pollution[['timestamp', 'pm25']]
elif 'pm1' in pollution.columns:
    pollution = pollution[['timestamp', 'pm1']]

# Resample to hourly (already hourly, but safe)
pollution = pollution.set_index('timestamp').resample('1h').mean().reset_index()

pollution.head()
# Out:
# parameter                 timestamp       pm25
# 0         2025-12-16 04:00:00+00:00  15.696000
# 1         2025-12-16 05:00:00+00:00  16.127667
# 2         2025-12-16 06:00:00+00:00  16.152500
# 3         2025-12-16 07:00:00+00:00  26.174833
# 4         2025-12-16 08:00:00+00:00  29.644333

# %%
pollution['timestamp'] = pd.to_datetime(pollution['timestamp'])

# REMOVE timezone
pollution['timestamp'] = pollution['timestamp'].dt.tz_localize(None)

# %%
df = traffic.merge(weather, on='timestamp', how='inner')
df = df.merge(pollution, on='timestamp', how='inner')

# %%
# Handle missing values
df = df.interpolate()

# Drop any remaining NaNs
df = df.dropna()

# Sort
df = df.sort_values('timestamp')

print(df.head())
print(df.shape)
# Out:
#             timestamp  traffic_volume  temperature  precipitation       pm25
# 0 2025-12-16 04:00:00             0.0         -1.0            0.0  15.696000
# 1 2025-12-16 05:00:00             0.0         -1.0            0.0  16.127667
# 2 2025-12-16 06:00:00             0.0         -1.0            0.0  16.152500
# 3 2025-12-16 07:00:00             0.0         -1.0            0.0  26.174833
# 4 2025-12-16 08:00:00             0.0         -1.0            0.0  29.644333
# (1004, 5)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['timestamp'], df['traffic_volume'], label='Traffic Volume')

# %%
df.tail()
# Out:
#                timestamp  traffic_volume  temperature  precipitation      pm25
# 999  2026-01-26 19:00:00           386.0         -3.9            0.4  3.194167
# 1000 2026-01-26 20:00:00           335.0         -3.9            0.4  3.566000
# 1001 2026-01-26 21:00:00           332.0         -3.9            0.4  1.731000
# 1002 2026-01-26 22:00:00           278.0         -3.9            0.4  0.700000
# 1003 2026-01-26 23:00:00           290.0         -3.9            0.4  0.972500

# %%
plt.plot(traffic['timestamp'], traffic['traffic_volume'], label='Traffic Volume')

# %%
traffic.tail()
# Out:
#                  timestamp  traffic_volume
# 228739 2026-02-03 19:00:00          1408.0
# 228740 2026-02-03 20:00:00           999.0
# 228741 2026-02-03 21:00:00           710.0
# 228742 2026-02-03 22:00:00           587.0
# 228743 2026-02-03 23:00:00           454.0

# %%
df.tail()
# Out:
#                timestamp  traffic_volume  temperature  precipitation      pm25
# 999  2026-01-26 19:00:00           386.0         -3.9            0.4  3.194167
# 1000 2026-01-26 20:00:00           335.0         -3.9            0.4  3.566000
# 1001 2026-01-26 21:00:00           332.0         -3.9            0.4  1.731000
# 1002 2026-01-26 22:00:00           278.0         -3.9            0.4  0.700000
# 1003 2026-01-26 23:00:00           290.0         -3.9            0.4  0.972500

# %%
df[df['traffic_volume'] ==0]
# Out:
#               timestamp  traffic_volume  temperature  precipitation       pm25
# 0   2025-12-16 04:00:00             0.0         -1.0            0.0  15.696000
# 1   2025-12-16 05:00:00             0.0         -1.0            0.0  16.127667
# 2   2025-12-16 06:00:00             0.0         -1.0            0.0  16.152500
# 3   2025-12-16 07:00:00             0.0         -1.0            0.0  26.174833
# 4   2025-12-16 08:00:00             0.0         -1.0            0.0  29.644333
# ..                  ...             ...          ...            ...        ...
# 831 2026-01-19 19:00:00             0.0         -0.9            0.0  16.142000
# 832 2026-01-19 20:00:00             0.0         -0.9            0.0  11.394500
# 833 2026-01-19 21:00:00             0.0         -0.9            0.0   8.086000
# 834 2026-01-19 22:00:00             0.0         -0.9            0.0   9.750333
# 835 2026-01-19 23:00:00             0.0         -0.9            0.0  16.522000
#
# [500 rows x 5 columns]

# %%
traffic[traffic['timestamp'] < "2019-01-01" ].tail()
# Out:
#                  timestamp  traffic_volume
# 166555 2018-12-31 19:00:00             0.0
# 166556 2018-12-31 20:00:00             0.0
# 166557 2018-12-31 21:00:00             0.0
# 166558 2018-12-31 22:00:00             0.0
# 166559 2018-12-31 23:00:00             0.0

# %%
weather.sort_values('timestamp').tail()
# Out:
#                 timestamp  temperature  precipitation
# 55700 2026-05-09 20:00:00          NaN            0.0
# 55701 2026-05-09 21:00:00          NaN            0.0
# 55702 2026-05-09 22:00:00          NaN            0.0
# 55703 2026-05-09 23:00:00          NaN            0.0
# 55704 2026-05-10 00:00:00          NaN            0.0

# %%
df
# Out:
#                timestamp  traffic_volume  temperature  precipitation  \
# 0    2025-12-16 04:00:00             0.0         -1.0            0.0
# 1    2025-12-16 05:00:00             0.0         -1.0            0.0
# 2    2025-12-16 06:00:00             0.0         -1.0            0.0
# 3    2025-12-16 07:00:00             0.0         -1.0            0.0
# 4    2025-12-16 08:00:00             0.0         -1.0            0.0
# ...                  ...             ...          ...            ...
# 999  2026-01-26 19:00:00           386.0         -3.9            0.4
# 1000 2026-01-26 20:00:00           335.0         -3.9            0.4
# 1001 2026-01-26 21:00:00           332.0         -3.9            0.4
# 1002 2026-01-26 22:00:00           278.0         -3.9            0.4
# 1003 2026-01-26 23:00:00           290.0         -3.9            0.4
#
#            pm25
# 0     15.696000
# 1     16.127667
# 2     16.152500
# 3     26.174833
# 4     29.644333
# ...         ...
# 999    3.194167
# 1000   3.566000
# 1001   1.731000
# 1002   0.700000
# 1003   0.972500
#
# [1004 rows x 5 columns]

# %%
traffic[traffic['timestamp'] > "2025-12-01 00:00:00"]
# Out:
#                  timestamp  traffic_volume
# 227185 2025-12-01 01:00:00           791.0
# 227186 2025-12-01 02:00:00           539.0
# 227187 2025-12-01 03:00:00           351.0
# 227188 2025-12-01 04:00:00           275.0
# 227189 2025-12-01 05:00:00           382.0
# ...                    ...             ...
# 228739 2026-02-03 19:00:00          1408.0
# 228740 2026-02-03 20:00:00           999.0
# 228741 2026-02-03 21:00:00           710.0
# 228742 2026-02-03 22:00:00           587.0
# 228743 2026-02-03 23:00:00           454.0
#
# [1559 rows x 2 columns]
